# %%
import pandas as pd

# %%
# Read csv
weather_data="weather.csv"
weather_data = pd.read_csv(weather_data)
weather_data
# Out:
#                 dt                         dt_iso  timezone        city_name  \
# 0        283996800  1979-01-01 00:00:00 +0000 UTC    -18000  Custom location
# 1        284000400  1979-01-01 01:00:00 +0000 UTC    -18000  Custom location
# 2        284004000  1979-01-01 02:00:00 +0000 UTC    -18000  Custom location
# 3        284007600  1979-01-01 03:00:00 +0000 UTC    -18000  Custom location
# 4        284011200  1979-01-01 04:00:00 +0000 UTC    -18000  Custom location
# ...            ...                            ...       ...              ...
# 372134  1594580400  2020-07-12 19:00:00 +0000 UTC    -14400  Custom location
# 372135  1594584000  2020-07-12 20:00:00 +0000 UTC    -14400  Custom location
# 372136  1594587600  2020-07-12 21:00:00 +0000 UTC    -14400  Custom location
# 372137  1594591200  2020-07-12 22:00:00 +0000 UTC    -14400  Custom location
# 372138  1594594800  2020-07-12 23:00:00 +0000 UTC    -14400  Custom location
#
# ...

# %%
# Drop city_name, lat, lon, NaN values, weather_id, weather_icon
# weather_data.drop(columns = ['city_name', 'lat','lon','weather_id','weather_icon'])

weather_data = weather_data.dropna(axis='columns')
weather_data
# Out:
#                 dt                         dt_iso  timezone   temp  \
# 0        283996800  1979-01-01 00:00:00 +0000 UTC    -18000   4.49
# 1        284000400  1979-01-01 01:00:00 +0000 UTC    -18000   4.54
# 2        284004000  1979-01-01 02:00:00 +0000 UTC    -18000   4.71
# 3        284007600  1979-01-01 03:00:00 +0000 UTC    -18000   6.24
# 4        284011200  1979-01-01 04:00:00 +0000 UTC    -18000   6.88
# ...            ...                            ...       ...    ...
# 372134  1594580400  2020-07-12 19:00:00 +0000 UTC    -14400  26.25
# 372135  1594584000  2020-07-12 20:00:00 +0000 UTC    -14400  26.07
# 372136  1594587600  2020-07-12 21:00:00 +0000 UTC    -14400  25.52
# 372137  1594591200  2020-07-12 22:00:00 +0000 UTC    -14400  24.84
# 372138  1594594800  2020-07-12 23:00:00 +0000 UTC    -14400  24.01
#
#         feels_like  temp_min  temp_max  pressure  humidity  wind_speed  \
# 0             0.33      3.24      5.62      1016        94        3.96
# ...

# %%
# Filter 10-07-2017 to 10-07-2020
weather_data = weather_data[(weather_data['dt'] >= 1499644800) & (weather_data['dt'] <= 1594339200)]
weather_data
# Out:
#                 dt                         dt_iso  timezone   temp  \
# 345603  1499644800  2017-07-10 00:00:00 +0000 UTC    -14400  23.02
# 345604  1499648400  2017-07-10 01:00:00 +0000 UTC    -14400  22.36
# 345605  1499652000  2017-07-10 02:00:00 +0000 UTC    -14400  21.04
# 345606  1499655600  2017-07-10 03:00:00 +0000 UTC    -14400  19.61
# 345607  1499659200  2017-07-10 04:00:00 +0000 UTC    -14400  19.33
# ...            ...                            ...       ...    ...
# 372061  1594324800  2020-07-09 20:00:00 +0000 UTC    -14400  32.47
# 372062  1594328400  2020-07-09 21:00:00 +0000 UTC    -14400  31.75
# 372063  1594332000  2020-07-09 22:00:00 +0000 UTC    -14400  31.25
# 372064  1594335600  2020-07-09 23:00:00 +0000 UTC    -14400  30.17
# 372065  1594339200  2020-07-10 00:00:00 +0000 UTC    -14400  28.13
#
#         feels_like  temp_min  temp_max  pressure  humidity  wind_speed  \
# 345603       19.81     20.00     25.00      1013        46        4.95
# ...

# %%
#jsonify
from pandas import DataFrame
weather_data.to_json('weather_data.json')
